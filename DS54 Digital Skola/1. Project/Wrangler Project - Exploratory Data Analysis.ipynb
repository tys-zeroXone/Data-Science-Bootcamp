# %% [markdown]
# # 0.&nbsp;Import Libraries

# %%
# Data Analysis
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## 0.1 Import Dataset

# %%
df = pd.read_csv('ds_salaries.csv')

# %%
df.shape
# Out:
# (3755, 11)

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
# 5       2023               SE              FT         Applied Scientist
# 6       2023               SE              FT         Applied Scientist
# 7       2023               SE              FT            Data Scientist
# 8       2023               SE              FT            Data Scientist
# 9       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# ...

# %%
df.tail(10)
# Out:
#       work_year experience_level employment_type  \
# 3745       2021               SE              FT
# 3746       2021               MI              FT
# 3747       2021               MI              FT
# 3748       2021               MI              FT
# 3749       2021               SE              FT
# 3750       2020               SE              FT
# 3751       2021               MI              FT
# 3752       2020               EN              FT
# 3753       2020               EN              CT
# 3754       2021               SE              FT
#
#                                job_title   salary salary_currency  \
# 3745            Director of Data Science   168000             USD
# 3746                      Data Scientist   160000             SGD
# 3747  Applied Machine Learning Scientist   423000             USD
# 3748                       Data Engineer    24000             EUR
# 3749                     Data Specialist   165000             USD
# ...

# %%
df['experience_level'].unique()
# Out:
# array(['SE', 'MI', 'EN', 'EX'], dtype=object)

# %% [markdown]
# - SE: Senior
# - MI: Mid
# - EN: Entry
# - EX: Executive

# %%
df['experience_level'].value_counts()
# Out:
# experience_level
# SE    2516
# MI     805
# EN     320
# EX     114
# Name: count, dtype: int64

# %%
df['employment_type'].unique()
# Out:
# array(['FT', 'CT', 'FL', 'PT'], dtype=object)

# %% [markdown]
# * FT: Full Time
# * CT: Contract
# * FL: Freelance
# * PT: Part Time

# %%
df['employment_type'].value_counts()
# Out:
# employment_type
# FT    3718
# PT      17
# CT      10
# FL      10
# Name: count, dtype: int64

# %%
display(df['employee_residence'].nunique())
display(df['employee_residence'].unique())
# Out:
# 78
# array(['ES', 'US', 'CA', 'DE', 'GB', 'NG', 'IN', 'HK', 'PT', 'NL', 'CH',
#        'CF', 'FR', 'AU', 'FI', 'UA', 'IE', 'IL', 'GH', 'AT', 'CO', 'SG',
#        'SE', 'SI', 'MX', 'UZ', 'BR', 'TH', 'HR', 'PL', 'KW', 'VN', 'CY',
#        'AR', 'AM', 'BA', 'KE', 'GR', 'MK', 'LV', 'RO', 'PK', 'IT', 'MA',
#        'LT', 'BE', 'AS', 'IR', 'HU', 'SK', 'CN', 'CZ', 'CR', 'TR', 'CL',
#        'PR', 'DK', 'BO', 'PH', 'DO', 'EG', 'ID', 'AE', 'MY', 'JP', 'EE',
#        'HN', 'TN', 'RU', 'DZ', 'IQ', 'BG', 'JE', 'RS', 'NZ', 'MD', 'LU',
#        'MT'], dtype=object)

# %%
display(df['company_location'].nunique())
display(df['company_location'].unique())
# Out:
# 72
# array(['ES', 'US', 'CA', 'DE', 'GB', 'NG', 'IN', 'HK', 'NL', 'CH', 'CF',
#        'FR', 'FI', 'UA', 'IE', 'IL', 'GH', 'CO', 'SG', 'AU', 'SE', 'SI',
#        'MX', 'BR', 'PT', 'RU', 'TH', 'HR', 'VN', 'EE', 'AM', 'BA', 'KE',
#        'GR', 'MK', 'LV', 'RO', 'PK', 'IT', 'MA', 'PL', 'AL', 'AR', 'LT',
#        'AS', 'CR', 'IR', 'BS', 'HU', 'AT', 'SK', 'CZ', 'TR', 'PR', 'DK',
#        'BO', 'PH', 'BE', 'ID', 'EG', 'AE', 'LU', 'MY', 'HN', 'JP', 'DZ',
#        'IQ', 'CN', 'NZ', 'CL', 'MD', 'MT'], dtype=object)

# %% [markdown]
# Catatan:
#
# - Ada kemungkinan negara yang tidak terdaftar di salah satu tapi tidak lainnya. Cari caranya!

# %%
# Countries in employee_residence but not company_location --> Company doesnt have entity in that respective country
residence_only = set(df['employee_residence']) - set(df['company_location'])

# Countries in company_location but not employee_residence --> Company has remote employee located in other country
company_only = set(df['company_location']) - set(df['employee_residence'])

# Combine the unique countries from both sets
country_differences = residence_only.union(company_only)

# %%
# Filter the original DataFrame for rows where company_location is in the country_differences
df_filtered = df[df['employee_residence'].isin(country_differences)]

# Count the number of companies for each country in the filtered DataFrame
company_counts = df_filtered['employee_residence'].value_counts()

display(company_counts)
# Out:
# employee_residence
# UZ    2
# KW    1
# CY    1
# DO    1
# TN    1
# BG    1
# JE    1
# RS    1
# Name: count, dtype: int64

# %%
# Filter the original DataFrame for rows where company_location is in the country_differences
df_filtered = df[df['company_location'].isin(country_differences)]

# Count the number of companies for each country in the filtered DataFrame
company_counts = df_filtered['company_location'].value_counts()

display(company_counts)
# Out:
# company_location
# AL    1
# BS    1
# Name: count, dtype: int64

# %%
# Untuk rename value agar lebih jelas
dict_exp_level = {
    'EN': 'Junior',
    'MI': 'Mid',
    'SE': 'Senior',
    'EX': 'Executive'
}

dict_employment_type = {
    'FT': 'Full Time',
    'PT': 'Part Time',
    'CT': 'Contract',
    'FL': 'Freelance'
}

dict_remote_ratio = {
    0: 'No Remote',
    50: 'Partially Remote',
    100: 'Fully Remote'
}

# %%
# Install pycountry if not already installed
# %pip install pycountry
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 71.7 MB/s eta 0:00:00
# ...

# %%
#Find country name for all country code
import pycountry

# given arrays
employee_residence = np.array(['ES', 'US', 'CA', 'DE', 'GB', 'NG', 'IN', 'HK', 'PT', 'NL', 'CH',
       'CF', 'FR', 'AU', 'FI', 'UA', 'IE', 'IL', 'GH', 'AT', 'CO', 'SG',
       'SE', 'SI', 'MX', 'UZ', 'BR', 'TH', 'HR', 'PL', 'KW', 'VN', 'CY',
       'AR', 'AM', 'BA', 'KE', 'GR', 'MK', 'LV', 'RO', 'PK', 'IT', 'MA',
       'LT', 'BE', 'AS', 'IR', 'HU', 'SK', 'CN', 'CZ', 'CR', 'TR', 'CL',
       'PR', 'DK', 'BO', 'PH', 'DO', 'EG', 'ID', 'AE', 'MY', 'JP', 'EE',
       'HN', 'TN', 'RU', 'DZ', 'IQ', 'BG', 'JE', 'RS', 'NZ', 'MD', 'LU',
       'MT'], dtype=object)

company_location = np.array(['ES', 'US', 'CA', 'DE', 'GB', 'NG', 'IN', 'HK', 'NL', 'CH', 'CF',
       'FR', 'FI', 'UA', 'IE', 'IL', 'GH', 'CO', 'SG', 'AU', 'SE', 'SI',
       'MX', 'BR', 'PT', 'RU', 'TH', 'HR', 'VN', 'EE', 'AM', 'BA', 'KE',
       'GR', 'MK', 'LV', 'RO', 'PK', 'IT', 'MA', 'PL', 'AL', 'AR', 'LT',
       'AS', 'CR', 'IR', 'BS', 'HU', 'AT', 'SK', 'CZ', 'TR', 'PR', 'DK',
       'BO', 'PH', 'BE', 'ID', 'EG', 'AE', 'LU', 'MY', 'HN', 'JP', 'DZ',
       'IQ', 'CN', 'NZ', 'CL', 'MD', 'MT'], dtype=object)

# combine and find unique codes
unique_codes = np.unique(np.concatenate([employee_residence, company_location]))

# create mapping of code to country name
dict_residency_country = {}

for code in unique_codes:
    try:
        country = pycountry.countries.get(alpha_2=code)
        dict_residency_country[code] = country.name if country else "Unknown"
    except LookupError:
        dict_residency_country[code] = "Unknown"

dict_residency_country
# Out:
# {'AE': 'United Arab Emirates',
#  'AL': 'Albania',
#  'AM': 'Armenia',
#  'AR': 'Argentina',
#  'AS': 'American Samoa',
#  'AT': 'Austria',
#  'AU': 'Australia',
#  'BA': 'Bosnia and Herzegovina',
#  'BE': 'Belgium',
#  'BG': 'Bulgaria',
#  'BO': 'Bolivia, Plurinational State of',
#  'BR': 'Brazil',
#  'BS': 'Bahamas',
#  'CA': 'Canada',
#  'CF': 'Central African Republic',
#  'CH': 'Switzerland',
#  'CL': 'Chile',
#  'CN': 'China',
#  'CO': 'Colombia',
#  'CR': 'Costa Rica',
#  'CY': 'Cyprus',
#  'CZ': 'Czechia',
#  'DE': 'Germany',
#  'DK': 'Denmark',
#  'DO': 'Dominican Republic',
#  'DZ': 'Algeria',
#  'EE': 'Estonia',
#  'EG': 'Egypt',
#  'ES': 'Spain',
#  'FI': 'Finland',
#  'FR': 'France',
#  'GB': 'United Kingdom',
#  'GH': 'Ghana',
#  'GR': 'Greece',
#  'HK': 'Hong Kong',
#  'HN': 'Honduras',
#  'HR': 'Croatia',
#  'HU': 'Hungary',
#  'ID': 'Indonesia',
#  'IE': 'Ireland',
#  'IL': 'Israel',
#  'IN': 'India',
#  'IQ': 'Iraq',
#  'IR': 'Iran, Islamic Republic of',
# ...

# %%
#count total unique country code in the employee residence and company location
len(dict_residency_country)
# Out:
# 80

# %% [markdown]
# # 1.&nbsp;Exploratory Data Analysis

# %% [markdown]
# ## 1.1 Check Null Values

# %%
df.isnull().head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary  \
# 0      False             False            False      False   False
# 1      False             False            False      False   False
# 2      False             False            False      False   False
# 3      False             False            False      False   False
# 4      False             False            False      False   False
#
#    salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# 0            False          False               False         False
# 1            False          False               False         False
# 2            False          False               False         False
# 3            False          False               False         False
# 4            False          False               False         False
#
#    company_location  company_size
# 0             False         False
# 1             False         False
# 2             False         False
# ...

# %%
df.isnull().sum() # cek jumlah data yang kosong
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
# Menampilkan jumlah nilai yang hilang per kolom
missing_values = df.isnull().sum()

missing_values_df = pd.DataFrame(
    data=missing_values,
    columns=['missing_values_count'],
)

missing_values_df
# Out:
#                     missing_values_count
# work_year                              0
# experience_level                       0
# employment_type                        0
# job_title                              0
# salary                                 0
# salary_currency                        0
# salary_in_usd                          0
# employee_residence                     0
# remote_ratio                           0
# company_location                       0
# company_size                           0

# %%
missing_values_df.plot(kind='bar');

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB

# %% [markdown]
# ## 1.2 Check Duplicate Data

# %% [markdown]
# ### 1.2.1 Copy Data

# %%
# Salin data sebelum transformasi
df_copy = df.copy()

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44      False
# 45      False
# 46      False
# 47      False
# 48      False
# 49      False
# 50      False
# 51      False
# 52      False
# 53      False
# 54      False
# 55      False
# 56      False
# 57      False
# 58      False
# 59      False
# 60      False
# 61      False
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(1171)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44      False
# 45      False
# 46      False
# 47      False
# 48      False
# 49      False
# 50      False
# 51      False
# 52      False
# 53      False
# 54      False
# 55      False
# 56      False
# 57      False
# 58      False
# 59      False
# 60      False
# 61      False
# ...

# %%
duplicated_row_mask = df.duplicated()
df[duplicated_row_mask]
# Out:
#       work_year experience_level employment_type                    job_title  \
# 115        2023               SE              FT               Data Scientist
# 123        2023               SE              FT           Analytics Engineer
# 153        2023               MI              FT                Data Engineer
# 154        2023               MI              FT                Data Engineer
# 160        2023               SE              FT                Data Engineer
# 163        2023               SE              FT            Applied Scientist
# 164        2023               SE              FT            Applied Scientist
# 167        2023               MI              FT                Data Engineer
# 168        2023               MI              FT                Data Engineer
# 171        2023               SE              FT                Data Engineer
# 173        2023               SE              FT            Applied Scientist
# ...

# %%
duplicated_row_mask = df.duplicated(keep=False)
df[duplicated_row_mask]
# Out:
#       work_year experience_level employment_type                    job_title  \
# 5          2023               SE              FT            Applied Scientist
# 6          2023               SE              FT            Applied Scientist
# 9          2023               SE              FT               Data Scientist
# 10         2023               SE              FT               Data Scientist
# 11         2023               SE              FT                 Data Analyst
# 12         2023               SE              FT                 Data Analyst
# 13         2023               EN              FT            Applied Scientist
# 14         2023               EN              FT            Applied Scientist
# 17         2023               SE              FT               Data Scientist
# 18         2023               SE              FT               Data Scientist
# 20         2023               MI              FT                 Data Analyst
# ...

# %%
df.iloc[114:116, :]
# Out:
#      work_year experience_level employment_type                  job_title  \
# 114       2022               EN              FT  Machine Learning Engineer
# 115       2023               SE              FT             Data Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 114   54000             CHF          56536                 CH           100
# 115  150000             USD         150000                 US             0
#
#     company_location company_size
# 114               CH            S
# 115               US            M

# %% [markdown]
# ### 1.2.2 Delete Duplicates

# %%
# Menghapus duplikasi
print(f"Jumlah duplikasi sebelum dihapus: {df_copy.duplicated().sum()}")

df_copy.drop_duplicates(inplace=True)
print(f"Jumlah duplikasi setelah dihapus: {df_copy.duplicated().sum()}")
# Out:
# Jumlah duplikasi sebelum dihapus: 1171
# Jumlah duplikasi setelah dihapus: 0

# %% [markdown]
# ## 1.3 Check Unique Values in Each Column

# %% [markdown]
# ### 1.3.1 Check Data Shape

# %%
df_copy.shape
# Out:
# (2584, 11)

# %% [markdown]
# ### 1.3.2 Check Data Type

# %%
df_copy.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2584 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           2584 non-null   int64
#  1   experience_level    2584 non-null   object
#  2   employment_type     2584 non-null   object
#  3   job_title           2584 non-null   object
#  4   salary              2584 non-null   int64
#  5   salary_currency     2584 non-null   object
#  6   salary_in_usd       2584 non-null   int64
#  7   employee_residence  2584 non-null   object
#  8   remote_ratio        2584 non-null   int64
#  9   company_location    2584 non-null   object
#  10  company_size        2584 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 242.2+ KB

# %% [markdown]
# ### 1.3.3 Check Data Stats

# %%
df_copy.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  2584.000000  2.584000e+03    2584.000000   2584.000000
# mean   2022.301084  2.103653e+05  133409.280186     50.483746
# std       0.749179  8.080375e+05   67136.837329     48.163707
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  9.000000e+04   84975.000000      0.000000
# 50%    2022.000000  1.346300e+05  130000.000000     50.000000
# 75%    2023.000000  1.825625e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %% [markdown]
# ### 1.3.4 Check Unique Values

# %%
 for col in df_copy.columns:
     if col == 'salary' or col == 'salary_in_usd':
         continue
     else:
         print(f"{col}: {df_copy[col].nunique()}")
         print(f"{df_copy[col].unique()}")
         print("-*-"*20)
# Out:
# work_year: 4
# [2023 2022 2020 2021]
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# experience_level: 4
# ['SE' 'MI' 'EN' 'EX']
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# employment_type: 4
# ['FT' 'CT' 'FL' 'PT']
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# job_title: 93
# ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
# ...

# %%
excepted_columns = [
    'salary',
    'salary_in_usd'
]
for col in df_copy.columns:
    if col not in excepted_columns:
        print(f"{col}: {df_copy[col].nunique()}")
        print(f"{df_copy[col].unique()}")
        print("-*-"*20)
        print("")
# Out:
# work_year: 4
# [2023 2022 2020 2021]
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
#
# experience_level: 4
# ['SE' 'MI' 'EN' 'EX']
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
#
# employment_type: 4
# ['FT' 'CT' 'FL' 'PT']
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
#
# job_title: 93
# ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
# ...

# %% [markdown]
# ### 1.3.5 Check Columns

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# ## 1.4 Rename Value for Better Understanding

# %%
dict_exp_level = {
    'EN': 'Junior',
    'MI': 'Mid',
    'SE': 'Senior',
    'EX': 'Executive'
}

dict_employment_type = {
    'FT': 'Full Time',
    'PT': 'Part Time',
    'CT': 'Contract',
    'FL': 'Freelance'
}

dict_remote_ratio = {
    0: 'No Remote',
    50: 'Partially Remote',
    100: 'Fully Remote'
}

# %% [markdown]
# ### 1.4.1 Replace Values

# %%
df_1 = df_copy.copy()

# %%
df_1['experience_level'] = (
    df_1['experience_level']
    .replace(dict_exp_level)
)

df_1['employment_type'] = (
    df_1['employment_type']
    .replace(dict_employment_type)
)

df_1['remote_ratio'] = (
    df_1['remote_ratio']
    .replace(dict_remote_ratio)
)

# %%
df_1.head(10)
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023           Senior       Full Time  Principal Data Scientist
# 1       2023              Mid        Contract               ML Engineer
# 2       2023              Mid        Contract               ML Engineer
# 3       2023           Senior       Full Time            Data Scientist
# 4       2023           Senior       Full Time            Data Scientist
# 5       2023           Senior       Full Time         Applied Scientist
# 6       2023           Senior       Full Time         Applied Scientist
# 7       2023           Senior       Full Time            Data Scientist
# 8       2023           Senior       Full Time            Data Scientist
# 9       2023           Senior       Full Time            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES  Fully Remote
# ...

# %% [markdown]
# ### 1.4.2 Map Values

# %%
df_2 = df_copy.copy()

# %%
df_2.insert(
    loc=list(df_2.columns).index('experience_level') + 1,
    column="experience_level_desc",
    value=df_2['experience_level'].map(dict_exp_level)
)

# %%
df_2.head()
# Out:
#    work_year experience_level experience_level_desc employment_type  \
# 0       2023               SE                Senior              FT
# 1       2023               MI                   Mid              CT
# 2       2023               MI                   Mid              CT
# 3       2023               SE                Senior              FT
# 4       2023               SE                Senior              FT
#
#                   job_title  salary salary_currency  salary_in_usd  \
# 0  Principal Data Scientist   80000             EUR          85847
# 1               ML Engineer   30000             USD          30000
# 2               ML Engineer   25500             USD          25500
# 3            Data Scientist  175000             USD         175000
# 4            Data Scientist  120000             USD         120000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 ES           100               ES            L
# ...

# %%
df_2.insert(
    loc=list(df_2.columns).index('employment_type') + 1,
    column="employment_type_desc",
    value=df_2['employment_type'].map(dict_employment_type)
)

# %%
df_2.head()
# Out:
#    work_year experience_level experience_level_desc employment_type  \
# 0       2023               SE                Senior              FT
# 1       2023               MI                   Mid              CT
# 2       2023               MI                   Mid              CT
# 3       2023               SE                Senior              FT
# 4       2023               SE                Senior              FT
#
#   employment_type_desc                 job_title  salary salary_currency  \
# 0            Full Time  Principal Data Scientist   80000             EUR
# 1             Contract               ML Engineer   30000             USD
# 2             Contract               ML Engineer   25500             USD
# 3            Full Time            Data Scientist  175000             USD
# 4            Full Time            Data Scientist  120000             USD
#
#    salary_in_usd employee_residence  remote_ratio company_location  \
# ...

# %%
df_2.insert(
    loc=list(df_2.columns).index('remote_ratio') + 1,
    column="remote_ratio_desc",
    value=df_2['remote_ratio'].map(dict_remote_ratio)
)

# %%
df_2.head()
# Out:
#    work_year experience_level experience_level_desc employment_type  \
# 0       2023               SE                Senior              FT
# 1       2023               MI                   Mid              CT
# 2       2023               MI                   Mid              CT
# 3       2023               SE                Senior              FT
# 4       2023               SE                Senior              FT
#
#   employment_type_desc                 job_title  salary salary_currency  \
# 0            Full Time  Principal Data Scientist   80000             EUR
# 1             Contract               ML Engineer   30000             USD
# 2             Contract               ML Engineer   25500             USD
# 3            Full Time            Data Scientist  175000             USD
# 4            Full Time            Data Scientist  120000             USD
#
#    salary_in_usd employee_residence  remote_ratio remote_ratio_desc  \
# ...

# %%
#Mapping country code dengan nama lengkap negara yang ada di employee_residence dan company_location berdasarkan list yg ada di dalam library "pycountry"

df_2.insert(
    loc=list(df_2.columns).index('employee_residence') + 1,
    column="employee_residence_country_name",
    value=df_2['employee_residence'].map(dict_residency_country)
)

df_2.insert(
    loc=list(df_2.columns).index('company_location') + 1,
    column="company_location_country_name",
    value=df_2['company_location'].map(dict_residency_country)
)

# %%
df_2.head()
# Out:
#    work_year experience_level experience_level_desc employment_type  \
# 0       2023               SE                Senior              FT
# 1       2023               MI                   Mid              CT
# 2       2023               MI                   Mid              CT
# 3       2023               SE                Senior              FT
# 4       2023               SE                Senior              FT
#
#   employment_type_desc                 job_title  salary salary_currency  \
# 0            Full Time  Principal Data Scientist   80000             EUR
# 1             Contract               ML Engineer   30000             USD
# 2             Contract               ML Engineer   25500             USD
# 3            Full Time            Data Scientist  175000             USD
# 4            Full Time            Data Scientist  120000             USD
#
#    salary_in_usd employee_residence employee_residence_country_name  \
# ...

# %% [markdown]
# ## 1.5 Group the Job title

# %% [markdown]
# ### Check Job Title

# %%
df_2['job_title'].unique()
# Out:
# array(['Principal Data Scientist', 'ML Engineer', 'Data Scientist',
#        'Applied Scientist', 'Data Analyst', 'Data Modeler',
#        'Research Engineer', 'Analytics Engineer',
#        'Business Intelligence Engineer', 'Machine Learning Engineer',
#        'Data Strategist', 'Data Engineer', 'Computer Vision Engineer',
#        'Data Quality Analyst', 'Compliance Data Analyst',
#        'Data Architect', 'Applied Machine Learning Engineer',
#        'AI Developer', 'Research Scientist', 'Data Analytics Manager',
#        'Business Data Analyst', 'Applied Data Scientist',
#        'Staff Data Analyst', 'ETL Engineer', 'Data DevOps Engineer',
#        'Head of Data', 'Data Science Manager', 'Data Manager',
#        'Machine Learning Researcher', 'Big Data Engineer',
#        'Data Specialist', 'Lead Data Analyst', 'BI Data Engineer',
#        'Director of Data Science', 'Machine Learning Scientist',
#        'MLOps Engineer', 'AI Scientist', 'Autonomous Vehicle Technician',
# ...

# %% [markdown]
# ### Grouping Function

# %%
# def assign_broader_category(job_title):

#     data_engineering = ["Data Engineer", "Data Analyst", "Analytics Engineer", "BI Data Analyst", "Business Data Analyst", "BI Developer", "BI Analyst", "Business Intelligence Engineer", "BI Data Engineer", "Power BI Developer"]
#     data_scientist = ["Data Scientist", "Applied Scientist", "Research Scientist", "3D Computer Vision Researcher", "Deep Learning Researcher", "AI/Computer Vision Engineer"]
#     machine_learning = ["Machine Learning Engineer", "ML Engineer", "Lead Machine Learning Engineer", "Principal Machine Learning Engineer"]
#     data_architecture = ["Data Architect", "Big Data Architect", "Cloud Data Architect", "Principal Data Architect"]
#     management = ["Data Science Manager", "Director of Data Science", "Head of Data Science", "Data Scientist Lead", "Head of Machine Learning", "Manager Data Management", "Data Analytics Manager"]

#     if job_title in data_engineering:
#         return "Data Engineering"
#     elif job_title in data_scientist:
#         return "Data Scientist"
#     elif job_title in machine_learning:
#         return "Machine Learning"
#     elif job_title in data_architecture:
#         return "Data Architecture"
#     elif job_title in management:
#         return "Management"
#     else:
#         return "Other"

# %%
category_mapping = {
      "Data Engineering": [
          "Data Engineer",
          "Data Analyst",
          "Analytics Engineer",
          "BI Data Analyst",
          "Business Data Analyst",
          "BI Developer",
          "BI Analyst",
          "Business Intelligence Engineer",
          "BI Data Engineer",
          "Power BI Developer",
      ],
      "Data Scientist": [
          "Data Scientist",
          "Applied Scientist",
          "Research Scientist",
          "3D Computer Vision Researcher",
          "Deep Learning Researcher",
          "AI/Computer Vision Engineer",
      ],
      "Machine Learning": [
          "Machine Learning Engineer",
          "ML Engineer",
          "Lead Machine Learning Engineer",
          "Principal Machine Learning Engineer",
      ],
      "Data Architecture": [
          "Data Architect",
          "Big Data Architect",
          "Cloud Data Architect",
          "Principal Data Architect",
      ],
      "Management": [
          "Data Science Manager",
          "Director of Data Science",
          "Head of Data Science",
          "Data Scientist Lead",
          "Head of Machine Learning",
          "Manager Data Management",
          "Data Analytics Manager",
      ],
  }


def assign_broader_category(job_title, mapper):
  """
    Assigns a broader category to a given job title.

    Args:
      job_title (str): The job title to categorize.

    Returns:
      str: The broader category the job title belongs to, or "Other" if no
      match is found.
    """

  for category, titles in category_mapping.items():
    if job_title in titles:
      return category

  return "Other"

# %%
df_2.insert(
    loc=list(df_2.columns).index('job_title') + 1,
    column="job_title_simplified",
    value=df_2['job_title'].apply(lambda x: assign_broader_category(x, category_mapping))
)

# %%
df_2.head()
# Out:
#    work_year experience_level experience_level_desc employment_type  \
# 0       2023               SE                Senior              FT
# 1       2023               MI                   Mid              CT
# 2       2023               MI                   Mid              CT
# 3       2023               SE                Senior              FT
# 4       2023               SE                Senior              FT
#
#   employment_type_desc                 job_title job_title_simplified  salary  \
# 0            Full Time  Principal Data Scientist                Other   80000
# 1             Contract               ML Engineer     Machine Learning   30000
# 2             Contract               ML Engineer     Machine Learning   25500
# 3            Full Time            Data Scientist       Data Scientist  175000
# 4            Full Time            Data Scientist       Data Scientist  120000
#
#   salary_currency  salary_in_usd employee_residence  \
# ...

# %%
df_2[df_2['job_title_simplified'] == 'Other']['job_title'].unique()
# Out:
# array(['Principal Data Scientist', 'Data Modeler', 'Research Engineer',
#        'Data Strategist', 'Computer Vision Engineer',
#        'Data Quality Analyst', 'Compliance Data Analyst',
#        'Applied Machine Learning Engineer', 'AI Developer',
#        'Applied Data Scientist', 'Staff Data Analyst', 'ETL Engineer',
#        'Data DevOps Engineer', 'Head of Data', 'Data Manager',
#        'Machine Learning Researcher', 'Big Data Engineer',
#        'Data Specialist', 'Lead Data Analyst',
#        'Machine Learning Scientist', 'MLOps Engineer', 'AI Scientist',
#        'Autonomous Vehicle Technician',
#        'Applied Machine Learning Scientist', 'Lead Data Scientist',
#        'Cloud Database Engineer', 'Financial Data Analyst',
#        'Data Infrastructure Engineer', 'Software Data Engineer',
#        'AI Programmer', 'Data Operations Engineer', 'Data Science Lead',
#        'Data Science Consultant', 'Data Analytics Specialist',
# ...

# %% [markdown]
# ## 1.6 Adjust Salary to Present Values

# %% [markdown]
# ### Inflation Rate

# %%
# Inflation rates
us_inflation_rates = {
    2019: 0.0181,
    2020: 0.0123,
    2021: 0.0470,
    2022: 0.065
}

global_inflation_rates = {
    2019: 0.0219,
    2020: 0.0192,
    2021: 0.0350,
    2022: 0.088
}

def adjust_salary(df):

    year = df['work_year']
    ori_salary = df['salary_in_usd']
    currency = df['salary_currency']

    if year == 2023:
        return ori_salary
    else:
        adjust_salary = ori_salary
        for y in range(year, 2023):
            if currency == 'USD':
                inflation_rate = us_inflation_rates[y]
            else:
                inflation_rate = global_inflation_rates[y]

            adjust_salary = adjust_salary * (1 + inflation_rate)

    return adjust_salary

# %%
df_2['adjusted_salary'] = df_2.apply(adjust_salary, axis=1)

# %%
df_2.head()
# Out:
#    work_year experience_level experience_level_desc employment_type  \
# 0       2023               SE                Senior              FT
# 1       2023               MI                   Mid              CT
# 2       2023               MI                   Mid              CT
# 3       2023               SE                Senior              FT
# 4       2023               SE                Senior              FT
#
#   employment_type_desc                 job_title job_title_simplified  salary  \
# 0            Full Time  Principal Data Scientist                Other   80000
# 1             Contract               ML Engineer     Machine Learning   30000
# 2             Contract               ML Engineer     Machine Learning   25500
# 3            Full Time            Data Scientist       Data Scientist  175000
# 4            Full Time            Data Scientist       Data Scientist  120000
#
#   salary_currency  salary_in_usd employee_residence  \
# ...

# %%
df_2.loc[df_2['company_location'] == 'ID', 'salary_currency']
# Out:
# 3061    INR
# 3139    USD
# Name: salary_currency, dtype: object

# %%
df_2.loc[df_2['company_location'] == 'ID', ['company_location', 'salary_currency']].drop_duplicates()
# Out:
#      company_location salary_currency
# 3061               ID             INR
# 3139               ID             USD

# %% [markdown]
# # SOAL No.1
# Show the median adjusted data scientist salary, for each experience level

# %% [markdown]
# ## JAWABAN No.1

# %%
#Mencari title baru yg termasuk dalam kategori "Data Scientist"
additional_titles = [
   "Machine Learning Research Engineer",
    "Deep Learning Engineer",
    "NLP Engineer",
    "Applied Data Scientist",
    "AI Scientist",
    "Machine Learning Researcher",
    "Applied Machine Learning Scientist",
    "Data Science Tech Lead",
    "Machine Learning Scientist",
    "Principal Data Scientist",
    "Product Data Scientist",
    "Data Science Lead",
    "Data Science Engineer",
    "Lead Data Scientist",
    "Staff Data Scientist",
    "Data Science Consultant",
    "Computer Vision Engineer",
]

category_mapping["Data Scientist"].extend(additional_titles)

# %%
#lakukan mapping ulang untuk setiap nama title "Data Scientist" yang baru ditambahkan
df_2['job_title_simplified'] = df_2['job_title'].replace({
    title: category
    for category, titles in category_mapping.items()
    for title in titles
})

# %%
#menampilkan daftar baru semua title "Data Scientist"
df_2[df_2['job_title_simplified'] == 'Data Scientist']['job_title'].unique()
# Out:
# array(['Principal Data Scientist', 'Data Scientist', 'Applied Scientist',
#        'Computer Vision Engineer', 'Research Scientist',
#        'Applied Data Scientist', 'Machine Learning Researcher',
#        'Machine Learning Scientist', 'AI Scientist',
#        'Applied Machine Learning Scientist', 'Lead Data Scientist',
#        'Data Science Lead', 'Deep Learning Researcher',
#        'Data Science Consultant', 'Deep Learning Engineer',
#        'Data Science Engineer', 'Machine Learning Research Engineer',
#        'NLP Engineer', '3D Computer Vision Researcher',
#        'Data Science Tech Lead', 'Product Data Scientist',
#        'Staff Data Scientist'], dtype=object)

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2584 entries, 0 to 3754
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   work_year                        2584 non-null   int64
#  1   experience_level                 2584 non-null   object
#  2   experience_level_desc            2584 non-null   object
#  3   employment_type                  2584 non-null   object
#  4   employment_type_desc             2584 non-null   object
#  5   job_title                        2584 non-null   object
#  6   job_title_simplified             2584 non-null   object
#  7   salary                           2584 non-null   int64
#  8   salary_currency                  2584 non-null   object
#  9   salary_in_usd                    2584 non-null   int64
#  10  employee_residence               2584 non-null   object
#  11  employee_residence_country_name  2584 non-null   object
# ...

# %%
df_2['experience_level'] = (
    df_2['experience_level']
    .replace(dict_exp_level)
)

df_2['employment_type'] = (
    df_2['employment_type']
    .replace(dict_employment_type)
)

df_2['remote_ratio'] = (
    df_2['remote_ratio']
    .replace(dict_remote_ratio)
)

df_2['employee_residence'] = (
    df_2['employee_residence']
    .replace(dict_residency_country)
)

df_2['company_location'] = (
    df_2['company_location']
    .replace(dict_residency_country)
)

# %%
df_2[df_2['job_title_simplified'] == 'Data Scientist'].groupby('experience_level')['adjusted_salary'].median().sort_values(ascending=False)
# Out:
# experience_level
# Executive    188350.000000
# Senior       162945.000000
# Mid           94884.000000
# Junior        72003.786183
# Name: adjusted_salary, dtype: float64

# %% [markdown]
# # SOAL No. 2
# Show the number of records for each company_location, sorted descending

# %% [markdown]
# ## JAWABAN No.2

# %%
df_2.groupby('company_location')['company_location'].count().sort_values(ascending=False)
# Out:
# company_location
# United States                      1929
# United Kingdom                      155
# Canada                               83
# India                                57
# Germany                              55
# Spain                                44
# France                               33
# Brazil                               15
# Portugal                             14
# Australia                            14
# Netherlands                          13
# Greece                               11
# Mexico                               10
# Ireland                               7
# Austria                               6
# Singapore                             6
# Japan                                 6
# Switzerland                           5
# Türkiye                               5
# Poland                                5
# Nigeria                               5
# Pakistan                              4
# Slovenia                              4
# ...

# %% [markdown]
# # SOAL No.3
# From this data, show the median adjusted salary of employee who works for company located in Indonesia, do you think that value represents the salary in Indonesia? why? why not?

# %% [markdown]
# ## JAWABAN No.3

# %%
df_2.loc[df_2['company_location'] == 'Indonesia', 'salary_currency'].value_counts()
# Out:
# salary_currency
# INR    1
# USD    1
# Name: count, dtype: int64

# %%
df_2.loc[df_2['company_location'] == 'Indonesia', 'adjusted_salary']
# Out:
# 3061    58116.608
# 3139    15975.000
# Name: adjusted_salary, dtype: float64

# %%
df_2.loc[df_2['company_location'] == 'Indonesia', ['job_title', 'salary_currency', 'adjusted_salary']]
# Out:
#            job_title salary_currency  adjusted_salary
# 3061  Data Scientist             INR        58116.608
# 3139    Data Analyst             USD        15975.000

# %%
# Konversi dari Indian Rupee ke Rupiah (1 INR = 188.39 IDR)
conversion_rate_inr_to_idr = 188.39

df_2.loc[df_2['company_location'] == 'Indonesia', 'adjusted_salary'] = (
    df_2.loc[df_2['company_location'] == 'Indonesia', 'adjusted_salary'] * conversion_rate_inr_to_idr
)

# Ubah mata uang ke IDR
df_2.loc[df_2['company_location'] == 'Indonesia', 'salary_currency'] = 'IDR'

# %%
pd.options.display.float_format = 'Rp{:,.0f}'.format

# %%
df_2.loc[df_2['company_location'] == 'Indonesia', ['job_title', 'salary_currency', 'adjusted_salary']]
# Out:
#            job_title salary_currency  adjusted_salary
# 3061  Data Scientist             IDR     Rp10,948,588
# 3139    Data Analyst             IDR      Rp3,009,530

# %%
df_2[df_2['company_location'] == 'Indonesia'].groupby('company_location')['adjusted_salary'].median()
# Out:
# company_location
# Indonesia   Rp6,979,059
# Name: adjusted_salary, dtype: float64

# %%
df_2[df_2['company_location'] == 'Indonesia'].groupby('company_location')['adjusted_salary'].median()
# Out:
# company_location
# Indonesia   Rp6,979,059
# Name: adjusted_salary, dtype: float64

# %% [markdown]
# # **Kesimpulan** <br>
#
# Terdapat beberapa temuan berdasarkan analisa dari data yang dilakukan:
# 1. Semakin tinggi level, maka akan berbanding lurus dengan besaran gaji
# 2. Ditemukan ada perusahaan yang berada di suatu negara tidak memiliki karyawan di negara tersebut, karena karyawannya bekerja secara remote di negara lain
# 3. Ditemukan ada karyawan yang berada di lokasi suatu negara, namun perusahaan tempat dia bekerja tidak memiliki entitas perwakilan di negara tersebut
# 4. Perlu ditambahkan deskripsi pada data yang bentuknya berupa kode seperti **experience_level, employment_type, remote_ratio, employee_residence** dan **company_location** sehingga data lebih mudah dimengerti
# 5. Terdapat beberapa **job title** yang belum dimapping secara tepat untuk kategori **"Data Scientist"** sehingga perlu direview kembali dan ditambahkan ke dalam mapping job title yang sudah ada sebelumnya
# 6. Sebelum analisa lebih lanjut untuk pengambilan keputusan, data gaji perlu disesuaikan dan diolah terlebih dahulu berdasarkan **mata uang Rupiah** yang berlaku di Indonesia sehingga semua data dalam kondisi seragam dan memperhitungkan faktor inflasi sehingga analisa data yang dilakukan bisa sesuai dengan konteks dan relevansi saat analisa dilakukan
